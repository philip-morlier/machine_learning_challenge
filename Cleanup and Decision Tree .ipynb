# %%
import pandas as pd
from sklearn import tree
import os

# %%
#importing converting csv to dataframe and dropping nan values
planets=pd.read_csv('resorces/cumulative.csv')
planets_0=planets.dropna(axis='columns')
planets_1=planets_0.dropna()
# Out:
#       rowid     kepid kepoi_name koi_disposition koi_pdisposition  \
# 0         1  10797460  K00752.01       CONFIRMED        CANDIDATE
# 1         2  10797460  K00752.02       CONFIRMED        CANDIDATE
# 2         3  10811496  K00753.01  FALSE POSITIVE   FALSE POSITIVE
# 3         4  10848459  K00754.01  FALSE POSITIVE   FALSE POSITIVE
# 4         5  10854555  K00755.01       CONFIRMED        CANDIDATE
# ...     ...       ...        ...             ...              ...
# 9559   9560  10031643  K07984.01  FALSE POSITIVE   FALSE POSITIVE
# 9560   9561  10090151  K07985.01  FALSE POSITIVE   FALSE POSITIVE
# 9561   9562  10128825  K07986.01       CANDIDATE        CANDIDATE
# 9562   9563  10147276  K07987.01  FALSE POSITIVE   FALSE POSITIVE
# 9563   9564  10156110  K07989.01  FALSE POSITIVE   FALSE POSITIVE
#
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0    9.488036
# 1                 0              0              0              0   54.418383
# 2                 0              1              0              0   19.899140
# 3                 0              1              0              0    1.736952
# 4                 0              0              0              0    2.525592
# ...             ...            ...            ...            ...         ...
# 9559              0              0              0              1    8.589871
# 9560              0              1              1              0    0.527699
# 9561              0              0              0              0    1.739849
# 9562              0              0              1              0    0.681402
# 9563              0              0              1              1    4.856035
#
#       koi_time0bk  koi_duration         ra        dec
# 0      170.538750       2.95750  291.93423  48.141651
# 1      162.513840       4.50700  291.93423  48.141651
# 2      175.850252       1.78220  297.00482  48.134129
# 3      170.307565       2.40641  285.53461  48.285210
# 4      171.595550       1.65450  288.75488  48.226200
# ...           ...           ...        ...        ...
# 9559   132.016100       4.80600  298.74921  46.973351
# 9560   131.705093       3.22210  297.18875  47.093819
# 9561   133.001270       3.11400  286.50937  47.163219
# 9562   132.181750       0.86500  294.16489  47.176281
# 9563   135.993300       3.07800  297.00977  47.121021
#
# [9564 rows x 14 columns]

# %%
#eliminating non confirmed cases from the dataframe and making a new dataframe
results=list(planets_1.koi_disposition.unique())
temp_list=[]
for i in range(0,2,1):
    new_frame=planets_1.loc[planets_1['koi_disposition']==results[i]]
    temp_list.append(new_frame)
data=temp_list[0].append(temp_list[1])

# %%
#saving target values for later
target = data['koi_disposition']
target_names = target.unique()

# %%
#droping all columns containing non numerical values 
columns=list(data)
for i in range(len(columns)):
    if type(data[(columns[i])][0])==str:
        data.drop([columns[i]],axis=1,inplace=True)

# %%
#dropping other non quantified columns
data.drop(['rowid','kepid'],axis=1,inplace=True)
# data=strong_evidence.dropna()

# %%
# data=strong_evidence.dropna()
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.9584472389283761

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.9786768726079825

# %%
feature_names = data.columns
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.27062600093377936, 'koi_fpflag_ss'),
#  (0.25900780826836106, 'koi_fpflag_nt'),
#  (0.17843818872604034, 'koi_fpflag_co'),
#  (0.09341515963068683, 'koi_period'),
#  (0.0699659875561347, 'koi_fpflag_ec'),
#  (0.04423882139614257, 'koi_duration'),
#  (0.040806631219065706, 'koi_time0bk'),
#  (0.023610875724063216, 'ra'),
#  (0.019890526545726175, 'dec')]

# %%
#this looks very good. We have a well performing model with two to four features which have clearly
#significant weight in regards to determining categorization of the celestial object.
